# %%
# Load the "autoreload" extension so that code can change
# %load_ext autoreload

# Always reload modules
# %autoreload 2

# %%
import pandas as pd

# %% [markdown]
# Humanitarian Task Data Exploration

# %%
humanitarian_train_filepath = "../data/raw/crisismmd_datasplit_agreed_label/task_humanitarian_text_img_agreed_lab_train.tsv"

humanitarian_train_df = pd.read_csv(humanitarian_train_filepath, sep="\t")
humanitarian_train_df
# Out:
#                 event_name            tweet_id              image_id  \
# 0     california_wildfires  917793137925459968  917793137925459968_0
# 1     california_wildfires  917793137925459968  917793137925459968_1
# 2     california_wildfires  917793137925459968  917793137925459968_2
# 3     california_wildfires  917815040962695168  917815040962695168_2
# 4     california_wildfires  917828283047260161  917828283047260161_0
# ...                    ...                 ...                   ...
# 6121       hurricane_maria  922480484227088384  922480484227088384_0
# 6122       hurricane_maria  922929267247169536  922929267247169536_0
# 6123      hurricane_harvey  908172698790055936  908172698790055936_0
# 6124      hurricane_harvey  906790326215614466  906790326215614466_0
# 6125      hurricane_harvey  907573287697477632  907573287697477632_0
#
#                                              tweet_text  \
# 0     RT @KAKEnews: California wildfires destroy mor...
# ...

# %%
humanitarian_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6126 entries, 0 to 6125
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   event_name        6126 non-null   object
#  1   tweet_id          6126 non-null   int64
#  2   image_id          6126 non-null   object
#  3   tweet_text        6126 non-null   object
#  4   image             6126 non-null   object
#  5   label             6126 non-null   object
#  6   label_text        6126 non-null   object
#  7   label_image       6126 non-null   object
#  8   label_text_image  6126 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 430.9+ KB

# %%
humanitarian_val_filepath = "../data/raw/crisismmd_datasplit_agreed_label/task_humanitarian_text_img_agreed_lab_dev.tsv"

humanitarian_val_df = pd.read_csv(humanitarian_val_filepath, sep="\t")
humanitarian_val_df
# Out:
#                event_name            tweet_id              image_id  \
# 0    california_wildfires  920329866901381123  920329866901381123_0
# 1          hurricane_irma  909744783115120640  909744783115120640_0
# 2          hurricane_irma  909925247331241984  909925247331241984_0
# 3          hurricane_irma  909819142970241024  909819142970241024_0
# 4         hurricane_maria  910526223918309376  910526223918309376_0
# ..                    ...                 ...                   ...
# 993        hurricane_irma  905642011801165825  905642011801165825_0
# 994        hurricane_irma  910192887723413505  910192887723413505_0
# 995       hurricane_maria  914159501984616448  914159501984616448_0
# 996        hurricane_irma  909944056582742016  909944056582742016_0
# 997     mexico_earthquake  911946489529798656  911946489529798656_0
#
#                                             tweet_text  \
# 0    Family Miraculously Finds Dog They Lost When E...
# ...

# %%
humanitarian_test_filepath = "../data/raw/crisismmd_datasplit_agreed_label/task_humanitarian_text_img_agreed_lab_test.tsv"

humanitarian_test_df = pd.read_csv(humanitarian_test_filepath, sep="\t")
humanitarian_test_df
# Out:
#                event_name            tweet_id              image_id  \
# 0        hurricane_harvey  905952332923338752  905952332923338752_0
# 1       mexico_earthquake  912022130396672000  912022130396672000_0
# 2         hurricane_maria  927758858776465408  927758858776465408_0
# 3        hurricane_harvey  907654309587779584  907654309587779584_0
# 4         hurricane_maria  913745586104528898  913745586104528898_0
# ..                    ...                 ...                   ...
# 950  iraq_iran_earthquake  930415579294584834  930415579294584834_0
# 951  california_wildfires  923088359089688577  923088359089688577_0
# 952     mexico_earthquake  910670262789709824  910670262789709824_0
# 953  california_wildfires  921130711863631872  921130711863631872_0
# 954      hurricane_harvey  904549453058715648  904549453058715648_0
#
#                                             tweet_text  \
# 0    .@Lendio has a great event tomorrow for both #...
# ...

# %% [markdown]
# Informative Task Data Exploration

# %%
informative_train_filepath = "../data/raw/crisismmd_datasplit_agreed_label/task_informative_text_img_agreed_lab_train.tsv"

informative_train_df = pd.read_csv(informative_train_filepath, sep="\t")
informative_train_df
# Out:
#                 event_name            tweet_id              image_id  \
# 0     california_wildfires  917791291823591425  917791291823591425_0
# 1     california_wildfires  917793137925459968  917793137925459968_0
# 2     california_wildfires  917793137925459968  917793137925459968_1
# 3     california_wildfires  917793137925459968  917793137925459968_2
# 4     california_wildfires  917815040962695168  917815040962695168_0
# ...                    ...                 ...                   ...
# 9596      hurricane_harvey  905114243871240192  905114243871240192_0
# 9597  california_wildfires  919938318795788288  919938318795788288_0
# 9598       hurricane_maria  911512002954067968  911512002954067968_0
# 9599       hurricane_maria  912341945430798336  912341945430798336_0
# 9600     mexico_earthquake  910700764808564736  910700764808564736_0
#
#                                              tweet_text  \
# 0     RT @Cal_OES: PLS SHARE: Weâ€™re capturing wild...
# ...

# %%
informative_val_filepath = "../data/raw/crisismmd_datasplit_agreed_label/task_informative_text_img_agreed_lab_dev.tsv"

informative_val_df = pd.read_csv(informative_val_filepath, sep="\t")
informative_val_df
# Out:
#                 event_name            tweet_id              image_id  \
# 0         hurricane_harvey  905064623199719425  905064623199719425_0
# 1          hurricane_maria  922857566220283904  922857566220283904_0
# 2     california_wildfires  920571592131915777  920571592131915777_0
# 3          hurricane_maria  923421787794395137  923421787794395137_0
# 4         hurricane_harvey  909926768194260992  909926768194260992_0
# ...                    ...                 ...                   ...
# 1568      hurricane_harvey  908439707301838848  908439707301838848_0
# 1569     mexico_earthquake  910750938272534528  910750938272534528_0
# 1570     mexico_earthquake  910658635851644928  910658635851644928_0
# 1571      hurricane_harvey  906341151061499910  906341151061499910_0
# 1572       hurricane_maria  928822277067636737  928822277067636737_0
#
#                                              tweet_text  \
# 0     We've lost track of how many houses/families @...
# ...

# %%
informative_test_filepath = "../data/raw/crisismmd_datasplit_agreed_label/task_informative_text_img_agreed_lab_test.tsv"

informative_test_df = pd.read_csv(informative_test_filepath, sep="\t")
informative_test_df
# Out:
#             event_name            tweet_id              image_id  \
# 0      srilanka_floods  878185882431389696  878185882431389696_0
# 1      hurricane_maria  910542719864397824  910542719864397824_0
# 2      hurricane_maria  913009824195104768  913009824195104768_0
# 3      hurricane_maria  916053383383011328  916053383383011328_0
# 4      hurricane_maria  922230253359116288  922230253359116288_0
# ...                ...                 ...                   ...
# 1529   srilanka_floods  872757606049304576  872757606049304576_0
# 1530    hurricane_irma  909468291558772737  909468291558772737_0
# 1531  hurricane_harvey  909442415924318209  909442415924318209_0
# 1532   srilanka_floods  879731058744242177  879731058744242177_0
# 1533  hurricane_harvey  908804643064496128  908804643064496128_0
#
#                                              tweet_text  \
# 0     Cristofer CLEMENTE MORA now in 2nd at aguille ...
# 1     Hurricane Maria batters Puerto Rico as a Cat 4...
# ...

# %%
from PIL import Image
import os
img = Image.open(os.path.join("../data/raw/CrisisMMD_v2.0/", informative_test_df.loc[0]["image"]))
print(informative_test_df.loc[0])
print(informative_test_df.loc[0]["tweet_text"])
img
# Out:
# event_name                                            srilanka_floods
# tweet_id                                           878185882431389696
# image_id                                         878185882431389696_0
# tweet_text          Cristofer CLEMENTE MORA now in 2nd at aguille ...
# image               data_image/srilanka_floods/23_6_2017/878185882...
# label                                                 not_informative
# label_text                                            not_informative
# label_image                                           not_informative
# label_text_image                                             Positive
# Name: 0, dtype: object
# Cristofer CLEMENTE MORA now in 2nd at aguille du posettes. He's hunting âš¡ï¸ #MontBlancMarathon 80k https://t.co/D7NLD18qWz
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x799 at 0x161B7FE50>
